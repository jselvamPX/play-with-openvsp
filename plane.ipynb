# %%
import openvsp as vsp

# %%
from src.coupled_loads_analysis import CoupledAeroStructAnalysis

# Initialize with your paths
coupled = CoupledAeroStructAnalysis(
    working_dir="supersonic_files",
    ccx_path="C:/path/to/ccx.exe"
)

# Run complete analysis
results = coupled.run_complete_analysis(
    sweep_angle=45,  # Delta wing sweep
    mach=2.0,         # Supersonic
    alpha=5.0         # Angle of attack
)

print(f"CL: {results['CL']}")
print(f"Max displacement: {results['max_displacement']} m")
# Out:
# === Running Analysis for Sweep=45°, M=2.0, α=5.0° ===
#
# Creating geometry...
# Running VSPAero analysis...
# /Users/jeevaselvam/play-with-openvsp/.venv/lib/python3.11/site-packages/openvsp/vspaero -omp 4 /Users/jeevaselvam/play-with-openvsp/supersonic_files/delta_wing_sweep45
# Setting Sref to: 100.000000
# Setting Cref to: 1.000000
# Setting Bref to: 1.000000
# Setting X_cg to: 0.000000
# Setting Y_cg to: 0.000000
# Setting Z_cg to: 0.000000
# Number of Machs: 1
# Mach: 2.000000
# Number of AoAs: 1
# AoA: 5.000000
# Number of Betas: 1
# Beta: 0.000000
# Number of ReCs: 1
# ReC: 10000000.000000
# Setting Vinf to: 100.000000
# Setting Rho to: 0.002377
# Setting StallModel to: 0
# Setting Clo2D to: 0.000000
# Setting CLMax2D to: 1.000000
# Setting Symmetry to: 0
# Setting FreezeMultiPoleAtIteration to: 10000
# Setting FreezeWakeAtIteration to: 10000
# Setting FreezeWakeRootVortices to: 0
# Setting ImplicitWake to: 0
# Setting ImplicitWakeStartIteration_ to: 0
# ...
